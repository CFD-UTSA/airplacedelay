# %%
import pandas as pd

# Read the files and import all rows.import pandas as pd


data= pd.read_csv('446901882_22021_4747_airline_delay_causes.csv')
data.head(20)
# Out:
#     year   month carrier carrier_name airport  \
# 0   2019       1      MQ    Envoy Air     SAV
# 1   2019       1      MQ    Envoy Air     SDF
# 2   2019       1      MQ    Envoy Air     SGF
# 3   2019       1      MQ    Envoy Air     SHV
# 4   2019       1      MQ    Envoy Air     SJT
# 5   2019       1      MQ    Envoy Air     SPI
# 6   2019       1      MQ    Envoy Air     SPS
# 7   2019       1      MQ    Envoy Air     SRQ
# 8   2019       1      MQ    Envoy Air     STL
# 9   2019       1      MQ    Envoy Air     SUX
# 10  2019       1      MQ    Envoy Air     SWO
# 11  2019       1      MQ    Envoy Air     SYR
# 12  2019       1      MQ    Envoy Air     TLH
# 13  2019       1      MQ    Envoy Air     TOL
# 14  2019       1      MQ    Envoy Air     TUL
# 15  2019       1      MQ    Envoy Air     TVC
# 16  2019       1      MQ    Envoy Air     TXK
# 17  2019       1      MQ    Envoy Air     TYR
# 18  2019       1      MQ    Envoy Air     TYS
# 19  2019       1      MQ    Envoy Air     XNA
#
#                                          airport_name  arr_flights  arr_del15  \
# 0    Savannah, GA: Savannah/Hilton Head International         65.0       15.0
# 1   Louisville, KY: Louisville Muhammad Ali Intern...         61.0       18.0
# 2       Springfield, MO: Springfield-Branson National        428.0       80.0
# 3                 Shreveport, LA: Shreveport Regional        174.0       28.0
# 4    San Angelo, TX: San Angelo Regional/Mathis Field        135.0       23.0
# 5            Springfield, IL: Abraham Lincoln Capital         53.0        5.0
# 6   Wichita Falls, TX: Sheppard AFB/Wichita Falls ...         88.0        8.0
# 7   Sarasota/Bradenton, FL: Sarasota/Bradenton Int...         31.0       13.0
# 8       St. Louis, MO: St Louis Lambert International         59.0       15.0
# 9   Sioux City, IA: Sioux Gateway Brig Gen Bud Day...        116.0       16.0
# 10                Stillwater, OK: Stillwater Regional         63.0        4.0
# 11       Syracuse, NY: Syracuse Hancock International        119.0       33.0
# 12         Tallahassee, FL: Tallahassee International        197.0       41.0
# 13                         Toledo, OH: Toledo Express         80.0       15.0
# 14                     Tulsa, OK: Tulsa International         83.0       22.0
# 15                  Traverse City, MI: Cherry Capital         50.0       11.0
# 16       Texarkana, AR: Texarkana Regional-Webb Field         87.0        8.0
# 17                   Tyler, TX: Tyler Pounds Regional        116.0       15.0
# 18                        Knoxville, TN: McGhee Tyson        138.0       27.0
# 19      Fayetteville, AR: Northwest Arkansas Regional        344.0       60.0
#
#     carrier_ct   weather_ct  ...  late_aircraft_ct  arr_cancelled  \
# 0         3.41         0.71  ...              6.56            1.0
# 1         2.70         1.01  ...              5.37            1.0
# 2        13.31         5.18  ...             34.09           15.0
# 3         5.97         1.17  ...              9.72            0.0
# 4        10.78         0.35  ...              5.33            2.0
# 5         2.91         0.00  ...              1.00            2.0
# 6         2.36         0.22  ...              2.97            6.0
# 7         1.25         0.55  ...              1.30            2.0
# 8         3.61         2.07  ...              4.28            7.0
# 9         0.00         1.69  ...              5.51           16.0
# 10        3.72         0.00  ...              0.00            2.0
# 11        5.95         3.02  ...              5.94           19.0
# 12       11.03         0.51  ...             14.12            3.0
# 13        1.28         2.64  ...              4.94           16.0
# 14        3.19         1.34  ...              6.40            9.0
# 15        1.50         0.30  ...              2.23            7.0
# 16        1.74         0.70  ...              2.81            0.0
# 17        4.43         0.98  ...              5.50            1.0
# 18        3.89         0.81  ...             10.74            7.0
# 19       15.60         3.82  ...             18.21           16.0
#
#     arr_diverted   arr_delay   carrier_delay  weather_delay  nas_delay  \
# 0            1.0       601.0           180.0           29.0      129.0
# 1            0.0       890.0           180.0           36.0      383.0
# 2            0.0      3954.0           705.0          213.0      982.0
# 3            0.0      1655.0           360.0           55.0      268.0
# 4            0.0       835.0           320.0           27.0      192.0
# 5            0.0       169.0           100.0            0.0       28.0
# 6            0.0       263.0            98.0            5.0       66.0
# 7            0.0       537.0            41.0           60.0      391.0
# 8            0.0       683.0           205.0           78.0      218.0
# 9            0.0       658.0             0.0           88.0      238.0
# 10           0.0        86.0            80.0            0.0        6.0
# 11           0.0      1618.0           396.0          161.0      760.0
# 12           1.0      1963.0           484.0           18.0      507.0
# 13           0.0       531.0            70.0           87.0      174.0
# 14           0.0      1017.0           141.0           56.0      444.0
# 15           0.0       350.0            34.0           16.0      203.0
# 16           0.0       377.0           127.0           51.0      107.0
# 17           1.0       589.0           176.0          143.0      103.0
# 18           1.0      1119.0           111.0           49.0      430.0
# 19           0.0      2603.0           774.0          202.0      895.0
#
#     security_delay  late_aircraft_delay  Unnamed: 21
# 0              0.0                263.0          NaN
# 1              0.0                291.0          NaN
# 2              0.0               2054.0          NaN
# 3              0.0                972.0          NaN
# 4              0.0                296.0          NaN
# 5              0.0                 41.0          NaN
# 6              0.0                 94.0          NaN
# 7              0.0                 45.0          NaN
# 8              0.0                182.0          NaN
# 9              0.0                332.0          NaN
# 10             0.0                  0.0          NaN
# 11             0.0                301.0          NaN
# 12             0.0                954.0          NaN
# 13             0.0                200.0          NaN
# 14             0.0                376.0          NaN
# 15             0.0                 97.0          NaN
# 16             0.0                 92.0          NaN
# 17             0.0                167.0          NaN
# 18             0.0                529.0          NaN
# 19             0.0                732.0          NaN
#
# [20 rows x 22 columns]

# %%
# Print out the number of rows imported from the files.
data.shape
# Out:
# (87860, 22)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-1c7d51d2623b> in <module>
#       1 # Change the data type of the 'month' column to date and change the format to YYYY-M (e.g. 2018-1).
# ----> 2 data['date'] = pd.to_datetime(data['date'], format='%Y-%m').dt.strftime('%Y-%m')
#       3
#       4 # Remove rows containing invalid data.
#       5 data = data[(data['date'] >= '2015-01') & (data['date'] <= '2021-02') & (data['arr_flights'].notnull())
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'date'

# %%
### Identify the airports in the state of Texas.
data['TX'] = data['airport_name'].apply(lambda x: x.find('TX'))

# Create a set of airport names (to eliminate the duplicates).
airports = set(data[data['TX'] != -1]['airport_name'])

# Display the list of airports.
print('Texas Airports:')
print(airports)
# Out:
# Tennessee Airports:
# {'Mission/McAllen/Edinburg, TX: McAllen Miller International', 'Waco, TX: Waco Regional', 'Brownsville, TX: Brownsville South Padre Island International', 'Victoria, TX: Victoria Regional', 'El Paso, TX: El Paso International', 'Dallas, TX: Dallas Love Field', 'Houston, TX: George Bush Intercontinental/Houston', 'College Station/Bryan, TX: Easterwood Field', 'Midland/Odessa, TX: Midland International Air and Space Port', 'Dallas/Fort Worth, TX: Dallas/Fort Worth International', 'Beaumont/Port Arthur, TX: Jack Brooks Regional', 'Austin, TX: Austin - Bergstrom International', 'Abilene, TX: Abilene Regional', 'Harlingen/San Benito, TX: Valley International', 'San Antonio, TX: San Antonio International', 'Longview, TX: East Texas Regional', 'Laredo, TX: Laredo International', 'Tyler, TX: Tyler Pounds Regional', 'Del Rio, TX: Del Rio International', 'Killeen, TX: Robert Gray AAF', 'Houston, TX: Ellington', 'Corpus Christi, TX: Corpus Christi International', 'Lubbock, TX: Lubbock Preston Smith International', 'Wichita Falls, TX: Sheppard AFB/Wichita Falls Municipal', 'San Angelo, TX: San Angelo Regional/Mathis Field', 'Houston, TX: William P Hobby', 'Amarillo, TX: Rick Husband Amarillo International'}
